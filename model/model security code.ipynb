# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os

# 1. First, check class distribution in your dataset
dataset_path = r"C:\College\dsmlcourse\DSML projects\dataset\model security dataset"

# Print number of images in each class folder
for class_name in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_name)
    if os.path.isdir(class_path):
        num_images = len([f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))])
        print(f"Class '{class_name}': {num_images} images")

# 2. Rebuild your model with class weights to handle imbalance
# Calculate class weights (more weight to underrepresented classes)
total_samples = sum([len(os.listdir(os.path.join(dataset_path, d))) 
                     for d in os.listdir(dataset_path) if os.path.isdir(os.path.join(dataset_path, d))])
class_weights = {}
for i, class_name in enumerate(os.listdir(dataset_path)):
    if os.path.isdir(os.path.join(dataset_path, class_name)):
        n_samples = len(os.listdir(os.path.join(dataset_path, class_name)))
        class_weights[i] = (1 / n_samples) * (total_samples / 3)  # 3 classes

print("Class weights:", class_weights)

# 3. Load the dataset with the EXACT same preprocessing for both training and inference
train_ds = keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    image_size=(224, 224),
    batch_size=15,
    validation_split=0.2,
    subset="training",
    seed=42
)

val_ds = keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    image_size=(224, 224),
    batch_size=15,
    validation_split=0.2,
    subset="validation",
    seed=42
)

# Save the EXACT class names from the dataset
class_names = train_ds.class_names
print("Actual class names from dataset:", class_names)

# 4. Create a preprocessing layer that will be part of the model
preprocessing = keras.Sequential([
    keras.layers.Rescaling(1./127.5, offset=-1)  # MobileNetV2 preprocessing
])

# Apply preprocessing consistently
train_ds = train_ds.map(lambda x, y: (preprocessing(x), y))
val_ds = val_ds.map(lambda x, y: (preprocessing(x), y))

# 5. Rebuild model with more capacity and regularization
base_model = keras.applications.MobileNetV2(
    weights="imagenet", 
    include_top=False, 
    input_shape=(224, 224, 3)
)
base_model.trainable = False  # Freeze base model

model = keras.Sequential([
    base_model,
    keras.layers.GlobalAveragePooling2D(),
    keras.layers.BatchNormalization(),
    keras.layers.Dense(256, activation="relu"),  # Larger intermediate layer
    keras.layers.Dropout(0.5),  # Strong dropout
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dropout(0.3),
    keras.layers.Dense(len(class_names), activation="softmax")
])

# 6. Compile with better optimization parameters
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),  # Lower learning rate
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# 7. Train with class weights to handle imbalance
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    class_weight=class_weights,  # Apply class weights
    callbacks=[
        keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
        keras.callbacks.ReduceLROnPlateau(factor=0.2, patience=3)
    ]
)

# 8. Save model and class names together
save_dir = r"C:\College\dsmlcourse\model_security_2"
os.makedirs(save_dir, exist_ok=True)

# Save class names to text file
with open(os.path.join(save_dir, "class_names.txt"), "w") as f:
    for name in class_names:
        f.write(name + "\n")

# Convert to TFLite with optimization
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

with open(os.path.join(save_dir, "model.tflite"), "wb") as f:
    f.write(tflite_model)

print("Model and class names saved to:", save_dir)
# Out:
# Class 'firesmoke': 100 images
# Class 'medical assist': 192 images
# Class 'normal': 192 images
# Class 'trackdefective': 147 images
# Class 'tracknotdefective': 201 images
# Class weights: {0: 2.773333333333333, 1: 1.4444444444444442, 2: 1.4444444444444442, 3: 1.8866213151927436, 4: 1.3797678275290215}
# Found 832 files belonging to 5 classes.
# Using 666 files for training.
# Found 832 files belonging to 5 classes.
# Using 166 files for validation.
# Actual class names from dataset: ['firesmoke', 'medical assist', 'normal', 'trackdefective', 'tracknotdefective']
# Epoch 1/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 19s 296ms/step - accuracy: 0.4514 - loss: 2.5489 - val_accuracy: 0.7771 - val_loss: 0.4875 - learning_rate: 5.0000e-04
# Epoch 2/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 269ms/step - accuracy: 0.8223 - loss: 0.7717 - val_accuracy: 0.9096 - val_loss: 0.2612 - learning_rate: 5.0000e-04
# Epoch 3/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 271ms/step - accuracy: 0.8551 - loss: 0.6516 - val_accuracy: 0.9337 - val_loss: 0.2146 - learning_rate: 5.0000e-04
# Epoch 4/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 271ms/step - accuracy: 0.8823 - loss: 0.4483 - val_accuracy: 0.9277 - val_loss: 0.1895 - learning_rate: 5.0000e-04
# Epoch 5/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 274ms/step - accuracy: 0.9088 - loss: 0.3567 - val_accuracy: 0.9337 - val_loss: 0.1749 - learning_rate: 5.0000e-04
# Epoch 6/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 270ms/step - accuracy: 0.8949 - loss: 0.3816 - val_accuracy: 0.9398 - val_loss: 0.1536 - learning_rate: 5.0000e-04
# Epoch 7/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 273ms/step - accuracy: 0.9107 - loss: 0.3068 - val_accuracy: 0.9337 - val_loss: 0.1447 - learning_rate: 5.0000e-04
# Epoch 8/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 275ms/step - accuracy: 0.9361 - loss: 0.2455 - val_accuracy: 0.9458 - val_loss: 0.1428 - learning_rate: 5.0000e-04
# Epoch 9/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 14s 301ms/step - accuracy: 0.9321 - loss: 0.2321 - val_accuracy: 0.9458 - val_loss: 0.1377 - learning_rate: 5.0000e-04
# Epoch 10/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 281ms/step - accuracy: 0.9631 - loss: 0.1827 - val_accuracy: 0.9458 - val_loss: 0.1271 - learning_rate: 5.0000e-04
# Epoch 11/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 278ms/step - accuracy: 0.9727 - loss: 0.1491 - val_accuracy: 0.9458 - val_loss: 0.1179 - learning_rate: 5.0000e-04
# Epoch 12/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 285ms/step - accuracy: 0.9618 - loss: 0.1534 - val_accuracy: 0.9458 - val_loss: 0.1286 - learning_rate: 5.0000e-04
# Epoch 13/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 281ms/step - accuracy: 0.9523 - loss: 0.1938 - val_accuracy: 0.9518 - val_loss: 0.1196 - learning_rate: 5.0000e-04
# Epoch 14/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 279ms/step - accuracy: 0.9699 - loss: 0.1277 - val_accuracy: 0.9458 - val_loss: 0.1148 - learning_rate: 5.0000e-04
# Epoch 15/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 285ms/step - accuracy: 0.9725 - loss: 0.0988 - val_accuracy: 0.9337 - val_loss: 0.1171 - learning_rate: 5.0000e-04
# Epoch 16/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 292ms/step - accuracy: 0.9715 - loss: 0.1310 - val_accuracy: 0.9337 - val_loss: 0.1395 - learning_rate: 5.0000e-04
# Epoch 17/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 284ms/step - accuracy: 0.9567 - loss: 0.1650 - val_accuracy: 0.9458 - val_loss: 0.1221 - learning_rate: 5.0000e-04
# Epoch 18/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 283ms/step - accuracy: 0.9735 - loss: 0.1182 - val_accuracy: 0.9458 - val_loss: 0.1140 - learning_rate: 1.0000e-04
# Epoch 19/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 285ms/step - accuracy: 0.9874 - loss: 0.0609 - val_accuracy: 0.9458 - val_loss: 0.1118 - learning_rate: 1.0000e-04
# Epoch 20/20
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 279ms/step - accuracy: 0.9725 - loss: 0.1048 - val_accuracy: 0.9458 - val_loss: 0.1109 - learning_rate: 1.0000e-04
# INFO:tensorflow:Assets written to: C:\Users\nadar\AppData\Local\Temp\tmpjcy35ajy\assets
# INFO:tensorflow:Assets written to: C:\Users\nadar\AppData\Local\Temp\tmpjcy35ajy\assets
# Saved artifact at 'C:\Users\nadar\AppData\Local\Temp\tmpjcy35ajy'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_816')
# Output Type:
#   TensorSpec(shape=(None, 5), dtype=tf.float32, name=None)
# Captures:
#   2630053108176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282658384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282657232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282658192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282658576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282658960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282660304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282660496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282660112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282659344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282660880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282662224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282662416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282662032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282661264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282662800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282664144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282664336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282663952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282663184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282664720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282666064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282666256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282665872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282665104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282666640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282667984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282668176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282667792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282667024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282668560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282669904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282670096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282669712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282668944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282670480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282670864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282999952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282657808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282669328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283000144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283001488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283001680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283001296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283000528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283002064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283003408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283003600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283003216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283002448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283003984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283005328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283005520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283005136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283004368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283005904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283007248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283007440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283007056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283006288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282657040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283009168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283009360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283008976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283007824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283009552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283010896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283011088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283010704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283009936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283011472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283012816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283013008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283012624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283011856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283013392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283014736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283014928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283014544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283013776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631282999376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283344208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283343632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283012240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283343440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283344976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283346320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283346512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283346128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283345360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283346896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283348240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283348432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283348048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283347280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283348816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283350160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283350352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283349968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283349200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283350736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283352080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283352272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283351888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283351120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283352656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283354000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283354192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283353808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283353040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283354576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283355920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283356112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283355728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283354960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283356496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283357840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283358032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283357648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283356880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283358416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283359568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283737040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283344592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283357264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283737232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283738576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283738768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283738384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283737424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283739152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283740496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283740688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283740304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283739536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283741072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283742416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283742608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283742224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283741456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283742992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283744336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283744528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283744144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283743376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283744912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283746256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283746448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283746064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283745296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283746832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283748176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283748368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283747984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283747216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283748752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283750096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283750288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283749904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283749136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283750672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283752016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283752208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283751824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283751056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283737616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284114256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284113680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631283749520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284113488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284115024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284116368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284116560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284116176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284115408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284116944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284118288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284118480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284118096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284117328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284118864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284120208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284120400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284120016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284119248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284120784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284122128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284122320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284121936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284121168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284122704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284124048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284124240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284123856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284123088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284124624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284125968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284126160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284125776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284125008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284126544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284127888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284128080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284127696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284126928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284128464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284129616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284490704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284114640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284127312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284490896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284492240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284492432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284492048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284491088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284492816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284494160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284494352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284493968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284493200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284494736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284496080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284496272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284495888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284495120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284496656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284498000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284498192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284497808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284497040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284498576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284499920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284500112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284499728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284498960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284500496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284501840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284502032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284501648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284500880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284502416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284503760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284503952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284503568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284502800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284504336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284505680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284505872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284505488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284504720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284491280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284900304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284900880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284503184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284901072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284901456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284902800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284902992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284902608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284901840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284904912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284904528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284905104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284905872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284906256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284907408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284907600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284908176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284908368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2631284908944: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model and class names saved to: C:\College\dsmlcourse\model_security_2

# %%
import tensorflow.lite as tflite
import numpy as np
from tensorflow.keras.preprocessing import image
import os

# Load the proper class names from your saved file
class_names_path = r"C:\College\dsmlcourse\model_security_2\class_names.txt"
with open(class_names_path, "r") as f:
    class_names = [line.strip() for line in f.readlines()]

print("Using these class names:", class_names)

# Load the TFLite model
interpreter = tflite.Interpreter(model_path=r"C:\College\dsmlcourse\model_security_2\model.tflite")
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

def predict_image(img_path):
    # Load and preprocess image exactly as in training
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    
    # Apply the EXACT SAME preprocessing as during training
    img_array = img_array / 127.5 - 1  # MobileNetV2 preprocessing
    
    # Run inference
    interpreter.set_tensor(input_details[0]['index'], img_array)
    interpreter.invoke()
    output = interpreter.get_tensor(output_details[0]['index'])
    
    # Get predicted class and confidence
    predicted_class = np.argmax(output[0])
    confidence = output[0][predicted_class]
    
    # Print all class probabilities for debugging
    for i, prob in enumerate(output[0]):
        print(f"  {class_names[i]}: {prob:.4f}")
    
    return predicted_class, confidence

# Test multiple images
test_images = [
r"C:\Users\nadar\Downloads\download.jpg"
]

for img_path in test_images:
    print(f"\nPredicting: {os.path.basename(img_path)}")
    predicted_class, confidence = predict_image(img_path)
    print(f"Predicted class: {class_names[predicted_class]}")
    print(f"Confidence: {confidence:.4f}")
# Out:
# Using these class names: ['firesmoke', 'medical assist', 'normal', 'trackdefective', 'tracknotdefective']
#
# Predicting: download.jpg
#   firesmoke: 0.9979
#   medical assist: 0.0003
#   normal: 0.0002
#   trackdefective: 0.0014
#   tracknotdefective: 0.0001
# Predicted class: firesmoke
# Confidence: 0.9979
